# %%
import pandas as pd
df = pd.read_csv('Google_Stock_Price.csv',index_col='Date',parse_dates=True)
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2010-01-04  15.689439  15.753504  15.621622  15.684434  15.684434   78169752
# 2010-01-05  15.695195  15.711712  15.554054  15.615365  15.615365  120067812
# 2010-01-06  15.662162  15.662162  15.174174  15.221722  15.221722  158988852
# 2010-01-07  15.250250  15.265265  14.831081  14.867367  14.867367  256315428
# 2010-01-08  14.814815  15.096346  14.742492  15.065566  15.065566  188783028

# %%
import matplotlib.pyplot as plt
plt.plot(df['Close'])
plt.xlabel('Time')
plt.ylabel('Closing Price')
plt.show()

# %%
close_prices = df[['Close']].values.reshape(-1,1)
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range=(0,1))
close_prices = sc.fit_transform(close_prices)

# %%
import numpy as np
def create_sequence(data, sequence_length):
    x,y = [],[]
    for i in range(sequence_length, len(data)):
        x.append(data[i-sequence_length:i,0])
        y.append(data[i,0])
    return np.array(x), np.array(y)

sequence_length = 60
x, y = create_sequence(close_prices,sequence_length)
x = x.reshape(x.shape[0],x.shape[1],1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, shuffle=False)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Input

model = Sequential ([
    Input(shape=(x.shape[1],1)),
    LSTM(50, return_sequences=True),
    LSTM(50),
    Dense(1)
])
model.compile(
    optimizer='adam',
    loss='mse'
)

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(
    patience=4,
    verbose=1,
    restore_best_weights=True
)
history = model.fit(
    x_train, y_train,
    validation_data = (x_test, y_test),
    epochs=10,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/10
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - loss: 0.0070 - val_loss: 0.0021
# Epoch 2/10
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 1.1621e-04 - val_loss: 0.0011
# Epoch 3/10
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 1.1620e-04 - val_loss: 0.0011
# Epoch 4/10
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.0423e-04 - val_loss: 0.0017
# Epoch 5/10
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 9.3109e-05 - val_loss: 9.8280e-04
# Epoch 6/10
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 1.2978e-04 - val_loss: 0.0013
# Epoch 7/10
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 9.9683e-05 - val_loss: 0.0021
# Epoch 8/10
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 8.9627e-05 - val_loss: 0.0014
# Epoch 9/10
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 9.3179e-05 - val_loss: 0.0010
# Epoch 9: early stopping
# Restoring model weights from the end of the best epoch: 5.

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training vs Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
y_pred = model.predict(x_test)
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step

# %%
from sklearn.metrics import r2_score as r2, mean_squared_error as mse, mean_absolute_error as mae
print("R2 Score: ", r2(y_test, y_pred))
print("MSE: ", mse(y_test,y_pred))
print("MAE: ", mae(y_test,y_pred))
# Out:
# R2 Score:  0.9643301537176382
# MSE:  0.0009827960628493516
# MAE:  0.025167598983667435

# %%
import matplotlib.pyplot as plt
plt.plot(y_test, color='Blue', label='Actual')
plt.plot(y_pred, color='Red', label='Predicted')
plt.legend()
plt.show()
